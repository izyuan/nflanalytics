# %%
import nfl_data_py as nfl
import pandas as pd

# %%
week_by_week2024 = nfl.import_weekly_data([2024], downcast=True)
play_by_play2024 = nfl.import_pbp_data([2024], downcast=True, cache=False, alt_path=None)
schedule2024 = nfl.import_schedules([2024])
seasonal2024 = nfl.import_seasonal_data([2024], "REG")
winstotal2024 = nfl.import_win_totals([2024])
# Out:
# Downcasting floats.
# 2024 done.
# Downcasting floats.
# WARNING:root:The win totals data source is currently in flux and may be out of date.

# %%
def get_ngs_data(stat_type, year):
    year_list = []
    year_list.append(int(year))
    df = nfl.import_ngs_data(stat_type, year_list)

    return df

# %%
passing_ngs =nfl.import_ngs_data("passing", [2024])

for columns in passing_ngs.columns:
    print(columns)
# Out:
# season
# season_type
# week
# player_display_name
# player_position
# team_abbr
# avg_time_to_throw
# avg_completed_air_yards
# avg_intended_air_yards
# avg_air_yards_differential
# aggressiveness
# max_completed_air_distance
# avg_air_yards_to_sticks
# attempts
# pass_yards
# pass_touchdowns
# interceptions
# passer_rating
# completions
# completion_percentage
# expected_completion_percentage
# completion_percentage_above_expectation
# avg_air_distance
# max_air_distance
# player_gsis_id
# player_first_name
# player_last_name
# player_jersey_number
# player_short_name

# %%
# Out:
# Downcasting floats.
#        ftn_game_id nflverse_game_id  season  week  ftn_play_id  \
# 0             6449   2024_01_BAL_KC    2024     1      1057995
# 1             6449   2024_01_BAL_KC    2024     1      1057996
# 2             6449   2024_01_BAL_KC    2024     1      1057997
# 3             6449   2024_01_BAL_KC    2024     1      1057998
# 4             6449   2024_01_BAL_KC    2024     1      1057999
# ...            ...              ...     ...   ...          ...
# 27914         6614  2024_11_HOU_DAL    2024    11      1085909
# 27915         6614  2024_11_HOU_DAL    2024    11      1085910
# 27916         6614  2024_11_HOU_DAL    2024    11      1085911
# 27917         6614  2024_11_HOU_DAL    2024    11      1085912
# 27918         6614  2024_11_HOU_DAL    2024    11      1085913
#
#        nflverse_play_id starting_hash qb_location  n_offense_backfield  \
# 0                    43             0           0                    0
# 1                    60             L           S                    1
# 2                    82             L           S                    0
# 3                   118             L           S                    1
# 4                   148             R           S                    1
# ...                 ...           ...         ...                  ...
# 27914              4826             L           S                    1
# 27915              4851             R           S                    1
# 27916              4873             M           S                    1
# 27917              4898             R           S                    1
# 27918              4921             R           S                    1
#
#        n_defense_box  ...  read_thrown  is_catchable_ball  is_contested_ball  \
# 0                  0  ...            0              False              False
# 1                  7  ...            0              False              False
# 2                  6  ...            1               True              False
# 3                  6  ...          CHK               True              False
# 4                  6  ...          CHK               True              False
# ...              ...  ...          ...                ...                ...
# 27914              6  ...          CHK               True              False
# 27915              6  ...            0              False              False
# 27916              5  ...            1               True              False
# 27917              6  ...            1              False              False
# 27918              4  ...            0              False              False
#
#        is_created_reception  is_drop  is_qb_sneak  n_blitzers  n_pass_rushers  \
# 0                     False    False        False           0               0
# 1                     False    False        False           0               0
# 2                     False    False        False           0               4
# 3                     False    False        False           0               4
# 4                     False    False        False           1               5
# ...                     ...      ...          ...         ...             ...
# 27914                 False    False        False           0               4
# 27915                 False    False        False           0               0
# 27916                 False    False        False           0               4
# 27917                 False    False        False           0               4
# 27918                 False    False        False           0               0
#
#        is_qb_fault_sack                      date_pulled
# 0                 False 2024-11-07 12:32:20.655396+00:00
# 1                 False 2024-11-07 12:32:20.655396+00:00
# 2                 False 2024-11-07 12:32:20.655396+00:00
# 3                 False 2024-11-07 12:32:20.655396+00:00
# 4                 False 2024-11-07 12:32:20.655396+00:00
# ...                 ...                              ...
# 27914             False 2024-11-20 12:31:36.648663+00:00
# 27915             False 2024-11-20 12:31:36.648663+00:00
# 27916             False 2024-11-20 12:31:36.648663+00:00
# 27917             False 2024-11-20 12:31:36.648663+00:00
# 27918             False 2024-11-20 12:31:36.648663+00:00
#
# [27919 rows x 29 columns]
